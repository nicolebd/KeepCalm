# %%
# R code for models regressing responses against events *only* as part of Analysis I:
# Understanding the Role of Events

# %%
# Load some packages
library(reshape2)
library(ggplot2)
library(cowplot)
library(ez)
library(nlme)
library(multcomp)
library(pastecs)
theme_set(theme_cowplot(font_size=8))
library(usdm)
library(r2glmm)
library(car)
library(MASS)
library(MCMCglmm)
library(lmerTest)
library(expss)
library(moments)

# %%
# Read signals
signals = read.csv("../metrics/all_events.csv")
colnames(signals)

# Set up planned contrasts
signals$Event = factor(signals$Event, levels=sort(unique(signals$Event)))
StopvsNoStop <- c(-1, 1, 1, -1)
TurnvsPass <- c(1, 0, 0, -1)
IntervsCarStop <- c(0, 1, -1, 0)
contrasts(signals$Event) <- cbind(StopvsNoStop, TurnvsPass, IntervsCarStop)
attr(signals$Event, "contrasts")
levels(signals$Event)
# Out:
#  [1] "pid"          "LatDist"      "LongDist"     "MaxVel"       "MeanVel"
#  [6] "MaxLatAcc"    "MeanLatAcc"   "MaxLongAcc"   "MeanLongAcc"  "MaxLatJerk"
# [11] "MeanLatJerk"  "MaxLongJerk"  "MeanLongJerk" "NumPks"       "MaxPkAmp"
# [16] "MeanScl"      "MeanEntropy"  "MaxEntropy"   "MeanDwell"    "MaxDwell"
# [21] "MeanHr"       "MaxHr"        "Event"        "Trial"
#   StopvsNoStop TurnvsPass IntervsCarStop
# 1 -1            1          0
# 2  1            0          1
# 3  1            0         -1
# 4 -1           -1          0
# [1] "1" "2" "3" "4"

# %%
# column indexes for the response/dependent variables of interest (NumPks, MaxPkAmp, MaxHR --
# MaxEntropy is handled separately due to missing data in signals)
response_ids = c(14, 15, 16, 21, 22)
entropy_response_ids = c(17, 18)
responses = colnames(signals)[response_ids]
entropy_responses = colnames(signals)[entropy_response_ids]

#---------------------------------------- Models ------------------------------------------#
non_entropy_models = lapply(responses, function(x) {
    lme(
        eval(substitute(resp ~ Event, list(resp = as.name(x)))),
        random = ~1|pid/Trial,
        data = signals,
        method = "ML"
    )
})

entropy_models = lapply(entropy_responses, function(x) {
    lme(
        eval(substitute(resp ~ Event, list(resp = as.name(x)))),
        random = ~1|pid/Trial,
        data = na.omit(signals),
        method = "ML"
    )
})

# %%
# Combine all models
event_models = c(non_entropy_models, entropy_models)

response_names = c(
    "NUMBER OF PEAKS",
    "MAX PEAK AMPLITUDE",
    "MEAN SCL", 
    "MEAN HR",
    "MAX HR",
    "MEAN ENTROPY",
    "MAX ENTROPY"
)
model_idx  = c(1:7)

# %%
cat("ALL MAIN EFFECTS\n")
cat("-------------------------------------------------------------------------------\n")

model_print = function(x, y, z){
    cat(y[x])
    cat("\n")
    print(summary(z[[x]]))
    cat("\n\n\n")
    cat("==============================================================================
    \n\n\n")
}

lapply(model_idx, model_print, y=response_names, z=event_models)
# Out:
# ALL MAIN EFFECTS
# -------------------------------------------------------------------------------
# NUMBER OF PEAKS
# Linear mixed-effects model fit by maximum likelihood
#  Data: signals
#        AIC      BIC    logLik
#   1017.109 1043.105 -501.5543
#
# Random effects:
#  Formula: ~1 | pid
#         (Intercept)
# StdDev:   0.5198782
#
#  Formula: ~1 | Trial %in% pid
#          (Intercept) Residual
# StdDev: 0.0001960215 1.212345
#
# Fixed effects: eval(substitute(resp ~ Event, list(resp = as.name(x))))
#                          Value  Std.Error  DF   t-value p-value
# (Intercept)          1.1310837 0.13663947 223  8.277869  0.0000
# EventStopvsNoStop    0.4866360 0.07012177 223  6.939871  0.0000
# EventTurnvsPass     -0.1937277 0.09903430 223 -1.956168  0.0517
# EventIntervsCarStop -0.0337890 0.09933990 223 -0.340135  0.7341
#  Correlation:
#                     (Intr) EvnSNS EvntTP
# EventStopvsNoStop    0.002
# EventTurnvsPass     -0.006  0.009
# EventIntervsCarStop -0.003 -0.005  0.000
#
# Standardized Within-Group Residuals:
#        Min         Q1        Med         Q3        Max
# -1.5961964 -0.5336846 -0.1321043  0.4066246 12.3163349
#
# Number of Observations: 303
# Number of Groups:
#            pid Trial %in% pid
#             20             77
#
#
#
# ==============================================================================
#
#
#
# MAX PEAK AMPLITUDE
# Linear mixed-effects model fit by maximum likelihood
#  Data: signals
#        AIC      BIC    logLik
#   198.4361 224.4322 -92.21803
#
# Random effects:
#  Formula: ~1 | pid
#         (Intercept)
# StdDev:    0.163027
#
#  Formula: ~1 | Trial %in% pid
#          (Intercept)  Residual
# StdDev: 2.767136e-05 0.3107914
#
# Fixed effects: eval(substitute(resp ~ Event, list(resp = as.name(x))))
#                           Value  Std.Error  DF   t-value p-value
# (Intercept)          0.20934877 0.04091626 223  5.116518  0.0000
# EventStopvsNoStop    0.15088876 0.01797627 223  8.393776  0.0000
# EventTurnvsPass     -0.04009986 0.02538909 223 -1.579413  0.1157
# EventIntervsCarStop -0.07054405 0.02546703 223 -2.770015  0.0061
#  Correlation:
#                     (Intr) EvnSNS EvntTP
# EventStopvsNoStop    0.002
# EventTurnvsPass     -0.005  0.009
# EventIntervsCarStop -0.003 -0.005  0.000
#
# Standardized Within-Group Residuals:
#         Min          Q1         Med          Q3         Max
# -2.88847042 -0.49759789 -0.05191758  0.32483776  5.83720787
#
# Number of Observations: 303
# Number of Groups:
#            pid Trial %in% pid
#             20             77
#
#
#
# ==============================================================================
#
#
#
# MEAN SCL
# Linear mixed-effects model fit by maximum likelihood
#  Data: signals
#         AIC       BIC   logLik
#   -203.8486 -177.8525 108.9243
#
# Random effects:
#  Formula: ~1 | pid
#          (Intercept)
# StdDev: 3.997446e-06
#
#  Formula: ~1 | Trial %in% pid
#          (Intercept) Residual
# StdDev: 2.936325e-06 0.168904
#
# Fixed effects: eval(substitute(resp ~ Event, list(resp = as.name(x))))
#                           Value   Std.Error  DF   t-value p-value
# (Intercept)          0.03532045 0.009768553 223  3.615730  0.0004
# EventStopvsNoStop    0.06428973 0.009768553 223  6.581295  0.0000
# EventTurnvsPass      0.00500031 0.013792452 223  0.362539  0.7173
# EventIntervsCarStop -0.03859567 0.013837153 223 -2.789278  0.0057
#  Correlation:
#                     (Intr) EvnSNS EvntTP
# EventStopvsNoStop    0.003
# EventTurnvsPass     -0.009  0.009
# EventIntervsCarStop -0.005 -0.005  0.000
#
# Standardized Within-Group Residuals:
#          Min           Q1          Med           Q3          Max
# -2.995513819 -0.519414941 -0.003986655  0.370689129  5.071892969
#
# Number of Observations: 303
# Number of Groups:
#            pid Trial %in% pid
#             20             77
#
#
#
# ==============================================================================
#
#
#
# MEAN HR
# Linear mixed-effects model fit by maximum likelihood
#  Data: signals
#        AIC      BIC    logLik
#   2541.353 2567.349 -1263.676
#
# Random effects:
#  Formula: ~1 | pid
#         (Intercept)
# StdDev:    14.74943
#
#  Formula: ~1 | Trial %in% pid
#         (Intercept) Residual
# StdDev:    6.530013 13.32815
#
# Fixed effects: eval(substitute(resp ~ Event, list(resp = as.name(x))))
#                         Value Std.Error  DF   t-value p-value
# (Intercept)         105.07069  3.492560 223 30.084143  0.0000
# EventStopvsNoStop    -0.32369  0.771174 223 -0.419742  0.6751
# EventTurnvsPass       0.18108  1.090147 223  0.166108  0.8682
# EventIntervsCarStop   0.29168  1.092727 223  0.266929  0.7898
#  Correlation:
#                     (Intr) EvnSNS EvntTP
# EventStopvsNoStop    0.001
# EventTurnvsPass     -0.004  0.008
# EventIntervsCarStop -0.002 -0.005  0.002
#
# Standardized Within-Group Residuals:
#         Min          Q1         Med          Q3         Max
# -2.77266325 -0.61594007 -0.08010338  0.56725723  4.48681134
#
# Number of Observations: 303
# Number of Groups:
#            pid Trial %in% pid
#             20             77
#
#
#
# ==============================================================================
#
#
#
# MAX HR
# Linear mixed-effects model fit by maximum likelihood
#  Data: signals
#        AIC      BIC    logLik
#   2770.567 2796.563 -1378.283
#
# Random effects:
#  Formula: ~1 | pid
#         (Intercept)
# StdDev:    15.44932
#
#  Formula: ~1 | Trial %in% pid
#         (Intercept) Residual
# StdDev:     6.59557 20.53637
#
# Fixed effects: eval(substitute(resp ~ Event, list(resp = as.name(x))))
#                         Value Std.Error  DF  t-value p-value
# (Intercept)         125.96619  3.756187 223 33.53566  0.0000
# EventStopvsNoStop     3.95187  1.188034 223  3.32639  0.0010
# EventTurnvsPass      -2.79619  1.678717 223 -1.66567  0.0972
# EventIntervsCarStop   0.85727  1.683290 223  0.50928  0.6111
#  Correlation:
#                     (Intr) EvnSNS EvntTP
# EventStopvsNoStop    0.001
# EventTurnvsPass     -0.004  0.009
# EventIntervsCarStop -0.002 -0.005  0.001
#
# Standardized Within-Group Residuals:
#         Min          Q1         Med          Q3         Max
# -2.26315010 -0.52411997 -0.08816004  0.37459946  3.44837006
#
# Number of Observations: 303
# Number of Groups:
#            pid Trial %in% pid
#             20             77
#
#
#
# ==============================================================================
#
#
#
# MEAN ENTROPY
# Linear mixed-effects model fit by maximum likelihood
#  Data: na.omit(signals)
#         AIC       BIC   logLik
#   -820.0299 -795.6946 417.0149
#
# Random effects:
#  Formula: ~1 | pid
#         (Intercept)
# StdDev:  0.03749258
#
#  Formula: ~1 | Trial %in% pid
#         (Intercept)   Residual
# StdDev:  0.01723375 0.03587162
#
# Fixed effects: eval(substitute(resp ~ Event, list(resp = as.name(x))))
#                           Value   Std.Error  DF   t-value p-value
# (Intercept)          0.20358973 0.009220448 175 22.080243  0.0000
# EventStopvsNoStop   -0.00286766 0.002341498 175 -1.224710  0.2223
# EventTurnvsPass      0.00584708 0.003309494 175  1.766761  0.0790
# EventIntervsCarStop  0.00311658 0.003319504 175  0.938868  0.3491
#  Correlation:
#                     (Intr) EvnSNS EvntTP
# EventStopvsNoStop    0.002
# EventTurnvsPass     -0.004  0.010
# EventIntervsCarStop -0.002 -0.006  0.002
#
# Standardized Within-Group Residuals:
#        Min         Q1        Med         Q3        Max
# -3.5347294 -0.5062804  0.1249771  0.5701018  2.3708583
#
# Number of Observations: 239
# Number of Groups:
#            pid Trial %in% pid
#             20             61
#
#
#
# ==============================================================================
#
#
#
# MAX ENTROPY
# Linear mixed-effects model fit by maximum likelihood
#  Data: na.omit(signals)
#         AIC      BIC   logLik
#   -821.9073 -797.572 417.9536
#
# Random effects:
#  Formula: ~1 | pid
#         (Intercept)
# StdDev:  0.03430182
#
#  Formula: ~1 | Trial %in% pid
#         (Intercept)   Residual
# StdDev:  0.01607799 0.03621604
#
# Fixed effects: eval(substitute(resp ~ Event, list(resp = as.name(x))))
#                           Value   Std.Error  DF   t-value p-value
# (Intercept)          0.24827467 0.008519101 175 29.143293  0.0000
# EventStopvsNoStop    0.00474191 0.002363859 175  2.006005  0.0464
# EventTurnvsPass      0.00417712 0.003340704 175  1.250372  0.2128
# EventIntervsCarStop -0.00110481 0.003351152 175 -0.329680  0.7420
#  Correlation:
#                     (Intr) EvnSNS EvntTP
# EventStopvsNoStop    0.002
# EventTurnvsPass     -0.005  0.010
# EventIntervsCarStop -0.002 -0.006  0.002
#
# Standardized Within-Group Residuals:
#         Min          Q1         Med          Q3         Max
# -4.22442796 -0.42809949  0.07685011  0.60872358  2.03835935
#
# Number of Observations: 239
# Number of Groups:
#            pid Trial %in% pid
#             20             61
#
#
#
# ==============================================================================
# [[1]]
# NULL
#
# [[2]]
# NULL
#
# [[3]]
# NULL
#
# [[4]]
# NULL
#
# [[5]]
# NULL
#
# [[6]]
# NULL
#
# [[7]]
# NULL
